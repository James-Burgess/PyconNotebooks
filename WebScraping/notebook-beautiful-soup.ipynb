# %% [markdown]
# # Beautiful Soup

# %% [markdown]
# Have a look at the Beautiful Soup [documentation](http://www.crummy.com/software/BeautifulSoup/bs4/doc/).

# %%
import bs4

bs4.__version__
# Out:
# '4.5.3'

# %%
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# ## Opening the Document ("Making the Soup")

# %%
URL = "http://bit.ly/2eL160q"
#URL = 'http://www.whatsmyua.info/api/v1/ua'

# %% [markdown]
# The first argument to the `BeautifulSoup` constructor is a string or open file handle.
#
# The second argument to the `BeautifulSoup` constructor is a parser. Potential values are (in order of decreasing merit):
#
# - `'lxml'` (XML parser)
# - `'html5lib'`
# - `'html.parser'` (Python’s built-in HTML parser).
#
# This will determine which library will be used to parse the content of the HTML document. Find out more about [specifying the parser](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#specifying-the-parser-to-use). If you don't specify a parser, Beautiful Soup will choose one for you.
#
# The choice of parser will affect the representation of a document in Beautiful Soup. For a perfectly formed HTML document this won't make any difference. However, if there are imperfections in the document then the way that each of these parsers attempts to fix the document will result in different internal representations.

# %%
with requests.get(URL) as r:
    soup = BeautifulSoup(r.text, 'html.parser')

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# You can also create soup directly from a local file.

# %% [markdown]
# The `prettify()` method produces a well formatted string representation.

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <meta content="171012896285253" property="fb:app_id"/>
#    <meta content="/browserconfig.xml" name="msapplication-config">
#     <meta content="1.3 ha farm in Byrne Valley, A historic home in Byrne Valley.
# A chance to own one of the first dwellings ever built in Byrne Vall" name="description"/>
#     <meta content="Private Property" property="og:site_name"/>
#     <meta content="en_us" property="og:locale"/>
#     <meta content="1.3 ha farm for sale in Byrne Valley | T479322 | Private Property" property="og:title"/>
#     <meta content="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-66071495_e.jpg" property="og:image"/>
#     <meta content="600" property="og:image:width"/>
#     <meta content="450" property="og:image:height"/>
#     <meta content="privatepropertyfb:property" property="og:type"/>
#     <meta content="https://www.privateproperty.co.za/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T479322" property="og:url"/>
#     <meta content="1.3 ha farm in Byrne Valley, A historic home in Byrne Valley.
# A chance to own one of the first dwellings ever built in Byrne Valley.  This historic home with wonderful views over the countryside, is set on a manageable 1.3 ha (ha..." property="og:description"/>
#     <link href="https://www.privateproperty.co.za/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T479322" rel="canonical"/>
#     <title>
#      1.3 ha farm for sale in Byrne Valley | T479322 | Private Property
#     </title>
#     <link href="/bundles/site.9f8c585f586a1d26313b.css" rel="stylesheet"/>
#     <link href="/bundles/listing.87f5645fc205aa02b88c.css" rel="stylesheet"/>
#     <!--[if lt IE 10]>
#         <link rel="stylesheet" href="/Content/Portal/Styles/Layouts/LegacyBrowsers/LegacyOverrides.css" />
#         <script src="/Scripts/Portal/ExternalLibraries/LegacyPolyfills/respond.matchmedia.addListener.min.js"></script>
#         <script src="/Scripts/Portal/ExternalLibraries/LegacyPolyfills/respond.min.js"></script>
#     <![endif]-->
#     <script type="text/javascript">
#      var appInsights = window.appInsights || function (config) {
#                 function i(config) { t[config] = function () { var i = arguments; t.queue.push(function () { t[config].apply(t, i) }) } } var t = { config: config }, u = document, e = window, o = "script", s = "AuthenticatedUserContext", h = "start", c = "stop", l = "Track", a = l + "Event", v = l + "Page", y = u.createElement(o), r, f; y.src = config.url || "https://az416426.vo.msecnd.net/scripts/a/ai.0.js"; u.getElementsByTagName(o)[0].parentNode.appendChild(y); try { t.cookie = u.cookie } catch (p) { } for (t.queue = [], t.version = "1.0", r = ["Event", "Exception", "Metric", "PageView", "Trace", "Dependency"]; r.length;) i("track" + r.pop()); return i("set" + s), i("clear" + s), i(h + a), i(c + a), i(h + v), i(c + v), i("flush"), config.disableExceptionTracking || (r = "onerror", i("_" + r), f = e[r], e[r] = function (config, i, u, e, o) { var s = f && f(config, i, u, e, o); return s !== !0 && t["_" + r](config, i, u, e, o), s }), t
#             }({
#                 instrumentationKey: "e6390f8a-ea54-45cd-85ec-82cfdac916a4",
#                 samplingPercentage: 10,
#                 disableExceptionTracking:true
#             });
#             window.appInsights = appInsights;
#             appInsights.trackPageView();
#     </script>
#     <script type="text/javascript">
#      var _viewStatsEvents = [{"Type":330,"EntityId":"2366552","LinkId":"1","Dim1":"1","Dim2":"3787","Dim3":"","IncBy":1}];
#         (function () {
#             var mf = document.createElement("script"); mf.type = "text/javascript"; mf.async = true;
#             mf.src = "/bundles/view-stats-startup.764bc8e945411431da62.bundle.js";
#             document.getElementsByTagName("head")[0].appendChild(mf);
#         })();
#     </script>
#     <script>
#      var _gaq = _gaq || [];
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#
#     var ppAdvertSlots = ppAdvertSlots || [];
#     var _trackEvent = _trackEvent || {};
#     </script>
#     <meta content="ftsdikeau1SzGd7D0Klyfz29o1PfGqkQ8AhTDx1GIwM" name="google-site-verification"/>
#     <script>
#      dataLayer = [
#                 {
#
#                     'listing-type' : 'Sales'
#                         ,
#                     'page' : 'ListingDetails'
#                         ,
#                     'contact-type' : 'Agent'
#                         ,
#                     'unique-id' : '2366552'
#                         ,
#                     'area' : 'Richmond and surrounds'
#                         ,
#                     'province' : 'KwaZulu Natal'
#                         ,
#                     'suburb' : 'Byrne Valley'
#                         ,
#                     'bedrooms' : '2'
#                         ,
#                     'price-grouping' : '1'
#                         ,
#                     'price' : 'R 700 000'
#
#                 }
#             ];
#     </script>
#     <script>
#      (function (w, d, s, l, i) {
#                 w[l] = w[l] || [];
#                 w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' });
#                 var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
#                 j.async = true;
#                 j.src = '//www.googletagmanager.com/gtm.js?id=' + i + dl;
#                 f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-WFJ7QJ');
#     </script>
#     <!-- Facebook Pixel Code -->
#     <script>
#      !function (f, b, e, v, n, t, s) {
#                 if (f.fbq) return; n = f.fbq = function () {
#                     n.callMethod ?
#                         n.callMethod.apply(n, arguments) : n.queue.push(arguments)
#                 }; if (!f._fbq) f._fbq = n;
#                 n.push = n; n.loaded = !0; n.version = '2.0'; n.queue = []; t = b.createElement(e); t.async = !0;
#                 t.src = v; s = b.getElementsByTagName(e)[0]; s.parentNode.insertBefore(t, s)
#             }(window,
#                 document, 'script', 'https://connect.facebook.net/en_US/fbevents.js');
#             fbq('init', '1499692390338215'); // Insert your pixel ID here.
#             fbq('track', 'PageView');
#     </script>
#     <noscript>
#      <img height="1" src="https://www.facebook.com/tr?id=1499692390338215&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#     </noscript>
#     <!-- DO NOT MODIFY -->
#     <!-- End Facebook Pixel Code -->
#    </meta>
#   </meta>
#  </head>
#  <body id="desktop">
#   <div id="fb-root">
#   </div>
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-WFJ7QJ" style="display: none; visibility: hidden" width="0">
#    </iframe>
#   </noscript>
#   <header>
#    <div class="wrapper">
#     <div class="row">
#      <a class="logo" href="/">
#      </a>
#      <nav class="siteNav row" id="siteNav">
#       <ul class="leftSide row searchVisible">
#        <li class="navigation relativePosition">
#         <a class="topMenu" href="#">
#          For Sale
#         </a>
#         <div class="dropDown leftRelativeToNavigation">
#          <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|7|3|10&amp;nostore=true" title="Property For Sale in Byrne Valley">
#           <span class="menuTitle">
#            All Property for Sale
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses For Sale in Byrne Valley">
#           <span class="menuTitle">
#            Houses For Sale
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments For Sale in Byrne Valley">
#           <span class="menuTitle">
#            Apartments For Sale
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes For Sale in Byrne Valley">
#           <span class="menuTitle">
#            Complexes For Sale
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/on-show/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Property On Show">
#           <span class="menuTitle">
#            Property On Show
#           </span>
#           <span class="desc">
#            On Show properties across South Africa
#           </span>
#          </a>
#          <a href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Property For Sale in Byrne Valley">
#           <span class="menuTitle">
#            Commercial Sales
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <hr/>
#          <a href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
#           <span class="menuTitle">
#            Estate Agents
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a href="/developments/South-Africa/1.htm" title="New homes in secure developments">
#           <span class="menuTitle">
#            Developments
#           </span>
#           <span class="desc">
#            New homes in secure developments
#           </span>
#          </a>
#          <a class="row" href="/bank-sales.htm" title="Bank Sales &amp; Repos">
#           <span class="menuTitle">
#            Bank Sales &amp; Repos
#           </span>
#           <span class="desc">
#            Repossessed homes at low prices
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/advice/property/buying-advice/3351" title="Advice for Buyers">
#           <span class="menuTitle">
#            Advice for Buyers
#           </span>
#           <span class="desc">
#            Expert advice on buying property
#           </span>
#          </a>
#          <a class="row" href="/Portal/PropertyAlerts" title="Receive Email Alerts">
#           <span class="menuTitle">
#            Receive Email Alerts
#           </span>
#           <span class="desc">
#            Receive notifications on new Properties For Sale
#           </span>
#          </a>
#         </div>
#        </li>
#        <li class="navigation relativePosition">
#         <a class="topMenu" href="#">
#          To Rent
#         </a>
#         <div class="dropDown leftRelativeToNavigation">
#          <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|11|3|7&amp;nostore=true" title="Property To Rent in Byrne Valley">
#           <span class="menuTitle">
#            Property To Rent
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses To Rent in Byrne Valley">
#           <span class="menuTitle">
#            Houses To Rent
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments To Rent in Byrne Valley">
#           <span class="menuTitle">
#            Apartments To Rent
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes To Rent in Byrne Valley">
#           <span class="menuTitle">
#            Complexes To Rent
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
#           <span class="menuTitle">
#            Commercial Rentals
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
#           <span class="menuTitle">
#            Estate Agents
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/advice/property/tenant-advice/3353" title="Advice for Tenants">
#           <span class="menuTitle">
#            Advice for Tenants
#           </span>
#           <span class="desc">
#            Expert advice on renting a property
#           </span>
#          </a>
#          <a class="row" href="/Portal/PropertyAlerts?listingType=Rentals" title="Receive Rental Email Alerts">
#           <span class="menuTitle">
#            Receive Email Alerts
#           </span>
#           <span class="desc">
#            Get notifications on new Property To Rent
#           </span>
#          </a>
#          <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile">
#           <span class="menuTitle">
#            Tenant VIP Profile
#           </span>
#           <span class="desc">
#            Apply for unlimited rentals online with VIP from Ekaya
#           </span>
#          </a>
#         </div>
#        </li>
#        <li class="navigation relativePosition">
#         <a class="topMenu" href="#">
#          Commercial
#         </a>
#         <div class="dropDown leftRelativeToNavigation">
#          <a class="row" href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Sales in Byrne Valley">
#           <span class="menuTitle widerTitle">
#            Commercial Sales
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
#           <span class="menuTitle widerTitle">
#            Commercial Rentals
#           </span>
#           <span class="desc">
#            in Byrne Valley
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/Portal/PropertyAlerts" title="Recieve Commercial Email Alerts">
#           <span class="menuTitle widerTitle">
#            Receive Email Alerts
#           </span>
#           <span class="desc">
#            Receive notifications on new Commercial Property
#           </span>
#          </a>
#         </div>
#        </li>
#        <li class="navigation">
#         <a class="topMenu" href="#">
#          Advice
#         </a>
#         <div class="dropDown rightRelativeToSiteNav">
#          <a class="row" href="/advice" title="Advice Centre">
#           <span class="menuTitle">
#            Advice Centre
#           </span>
#           <span class="desc">
#            All your property related advice in one spot
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/advice/property" title="Property Advice">
#           <span class="menuTitle">
#            Property Advice
#           </span>
#           <span class="desc">
#            Insights for buyers, sellers, landlords and tenants
#           </span>
#          </a>
#          <a class="row" href="/advice/news" title="News">
#           <span class="menuTitle">
#            News
#           </span>
#           <span class="desc">
#            Breaking news in the SA property market
#           </span>
#          </a>
#          <a class="row" href="/advice/lifestyle" title="Lifestyle and Decor">
#           <span class="menuTitle">
#            Lifestyle and Decor
#           </span>
#           <span class="desc">
#            Handy maintenance, decor and DIY tips
#           </span>
#          </a>
#          <a class="row" href="/neighbourhoods" title="Neighbourhoods">
#           <span class="menuTitle">
#            Neighbourhoods
#           </span>
#           <span class="desc">
#            Get to know SA's best neighbourhoods
#           </span>
#          </a>
#          <a class="row" href="/advice/property-tv" title="Property TV">
#           <span class="menuTitle">
#            Property TV
#           </span>
#           <span class="desc">
#            Catch up on our TV show appearances
#           </span>
#          </a>
#          <a class="row" href="/advice/agent-advice" title="Agent Advice">
#           <span class="menuTitle">
#            Agent Advice
#           </span>
#           <span class="desc">
#            Great advice for industry professionals
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="http://eepurl.com/PnGeL" target="_blank" title="Newsletter">
#           <span class="menuTitle">
#            Newsletter
#           </span>
#           <span class="desc">
#            General and investment advice on the property market
#           </span>
#          </a>
#         </div>
#        </li>
#        <li class="navigation">
#         <a class="topMenu" href="#">
#          Services
#         </a>
#         <div class="dropDown rightRelativeToSiteNav">
#          <a class="row" href="/list-your-property/list-for-sale.htm" title="Sell Your Property">
#           <span class="menuTitle widerTitle">
#            Sell Your Property
#           </span>
#           <span class="desc">
#            Advertise your property to millions of interested buyers
#           </span>
#          </a>
#          <a class="row" href="/list-your-property/list-to-rent.htm" title="Let Your Property">
#           <span class="menuTitle widerTitle">
#            Rent Your Property
#           </span>
#           <span class="desc">
#            <em class="greenText">
#             Free to advertise
#            </em>
#            on SA's largest rental platform
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile">
#           <span class="menuTitle widerTitle">
#            Tenant VIP Profile
#           </span>
#           <span class="desc">
#            Apply for unlimited rentals online with VIP from Ekaya
#           </span>
#          </a>
#          <a class="row" href="/advice/property/articles/ekaya-vip-a-smart-solution-for-smart-landlords/5781" title="Tenant Vetting">
#           <span class="menuTitle widerTitle">
#            Tenant Vetting
#           </span>
#           <span class="desc">
#            Vet all your potential tenants with VIP from Ekaya
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/bond-calculator.htm?rt=bondcalcmenu" title="Bond Repayments Calculator">
#           <span class="menuTitle widerTitle">
#            Bond Calculator
#           </span>
#           <span class="desc">
#            Calculate the monthly repayments on your bond
#           </span>
#          </a>
#          <a class="row" href="/bond-affordability-calculator.htm?rt=affordabilitycalcmenu" title="Bond Affordability Calculator">
#           <span class="menuTitle widerTitle">
#            Affordability Calculator
#           </span>
#           <span class="desc">
#            Calculate the maximum bond you can afford
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/ooba">
#           <span class="menuTitle widerTitle">
#            ooba Home Loans
#           </span>
#           <span class="desc">
#            Get prequalified for a home loan today.
#           </span>
#          </a>
#          <a class="row" href="/betterbond">
#           <span class="menuTitle widerTitle">
#            Better Bond Home Loans
#           </span>
#           <span class="desc">
#            We get you preapproved so you know what you can afford.
#           </span>
#          </a>
#          <a class="row" href="/bridging_finance.htm" title="Bridging Finance">
#           <span class="menuTitle widerTitle">
#            Bridging Finance
#           </span>
#           <span class="desc">
#            Access your funds immediately after selling your property
#           </span>
#          </a>
#          <hr/>
#          <a class="row" href="/attorneys/list/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Attorney Database">
#           <span class="menuTitle widerTitle">
#            Attorney Directory
#           </span>
#           <span class="desc">
#            Find a good attorney in your area
#           </span>
#          </a>
#          <a class="row" href="/estate-agents-in-south-africa" title="Find an Agent">
#           <span class="menuTitle widerTitle">
#            Find an Agent
#           </span>
#           <span class="desc">
#            Find a good estate agent in your area
#           </span>
#          </a>
#          <a class="row" href="/list-your-property/list-as-an-agent.htm" title="Advertise Your Agency">
#           <span class="menuTitle widerTitle">
#            Advertise Your Agency
#           </span>
#           <span class="desc">
#            Join other top estate agencies on Private Property
#           </span>
#          </a>
#          <a class="row" href="/rebosa" title="Rebosa">
#           <span class="menuTitle widerTitle">
#            REBOSA
#           </span>
#           <span class="desc">
#            Private Property is the exclusive portal partner to REBOSA
#           </span>
#          </a>
#         </div>
#        </li>
#       </ul>
#       <ul class="rightSide row">
#        <li class="search navigation">
#         <a class="topMenu" href="#" id="menuSearch">
#          Search
#         </a>
#         <div class="dropDown rightRelativeToSiteNav">
#          <div id="menuSeachBox">
#          </div>
#          <div class="suggestions row">
#           <div class="nearby">
#            <div class="searchHeading">
#             Nearby Suburbs and Areas
#            </div>
#            <ul id="nearbyShapes">
#             <li>
#              <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/richmond/88" title="Richmond">
#               Richmond
#              </a>
#             </li>
#             <li>
#              <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/ixopo/1463" title="Ixopo">
#               Ixopo
#              </a>
#             </li>
#             <li>
#              <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/creighton/1462" title="Creighton">
#               Creighton
#              </a>
#             </li>
#            </ul>
#           </div>
#           <div class="recentSearches">
#            <div class="searchHeading">
#             Recent Searches
#            </div>
#            <ul id="recentSearches">
#            </ul>
#           </div>
#          </div>
#         </div>
#        </li>
#        <li class="login">
#         <a class="topMenu" href="#" id="loginSignup">
#          <div id="loginIcon">
#          </div>
#          Sign In
#         </a>
#         <div class="dropDown rightRelativeToSiteNav">
#          <a class="modalLink" href="#login" title="Sign In">
#           <span class="menuTitle narrowerTitle">
#            Sign In
#           </span>
#           <span class="desc">
#            Have an existing account?
#           </span>
#          </a>
#          <a class="modalLink" href="#signup" title="Register">
#           <span class="menuTitle narrowerTitle">
#            Register
#           </span>
#           <span class="desc">
#            Create a new account
#           </span>
#          </a>
#          <hr/>
#          <a class="menuTitle" href="/Portal/AccountHolders/ForgotPassword?returnUrl=%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322" title="Forgot Your Password">
#           <span class="menuTitle">
#            Forgot Your Password
#           </span>
#          </a>
#         </div>
#        </li>
#       </ul>
#      </nav>
#     </div>
#     <div class="breadcrumbContainer ">
#      <div class="breadcrumb">
#       <a class="previousPage" href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" id="backButton" title="Byrne Valley">
#        Back to
#        <span class="backlink">
#         Byrne Valley
#        </span>
#       </a>
#       <span class="mainCrumbs">
#        <a href="/">
#         Property For Sale
#        </a>
#        <span class="crumbSeparator">
#         &gt;
#        </span>
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a href="/for-sale/kwazulu-natal/2" itemprop="url">
#          <span itemprop="title">
#           KwaZulu Natal
#          </span>
#         </a>
#         <span class="crumbSeparator">
#          &gt;
#         </span>
#        </span>
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a href="/for-sale/kwazulu-natal/drakensberg/2530" itemprop="url">
#          <span itemprop="title">
#           Drakensberg
#          </span>
#         </a>
#         <span class="crumbSeparator">
#          &gt;
#         </span>
#        </span>
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/2533" itemprop="url">
#          <span itemprop="title">
#           Richmond and surrounds
#          </span>
#         </a>
#         <span class="crumbSeparator">
#          &gt;
#         </span>
#        </span>
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" itemprop="url">
#          <span itemprop="title">
#           Byrne Valley
#          </span>
#         </a>
#         <span class="crumbSeparator">
#          &gt;
#         </span>
#        </span>
#        <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#         <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T479322" itemprop="url">
#          <span itemprop="title">
#           T479322
#          </span>
#         </a>
#        </span>
#       </span>
#      </div>
#     </div>
#    </div>
#   </header>
#   <section id="content">
#    <div class="row " id="details">
#     <div class="contactDocker" style="background-color:#121F49;">
#      <div class="backgroundColorHolder">
#       <div class="brandColor" style="background-color:#121F49">
#       </div>
#       <div class="bgColor">
#       </div>
#      </div>
#      <div class="wrapper row">
#       <div class="contactInfo row" style="background-color:#121F49;color:#fff">
#        <div class="listingInfo">
#         <p class="title">
#          1.3 ha farm in Byrne Valley
#         </p>
#         <p class="price">
#          <span class="detailsCurrencySymbol">
#           R
#          </span>
#          <span class="detailsPrice">
#           700 000
#          </span>
#         </p>
#        </div>
#        <div class="swiper-container contact" id="contactDockerGallery">
#         <div class="swiper-wrapper">
#          <div class="swiper-slide swiper-no-swiping">
#           <p class="name">
#            Vanessa Foxon
#           </p>
#           <p class="agencyName">
#            Dormehl Property Group-Howick
#           </p>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="contactButtons">
#        <button class="orangeButton" data-account-holder-id="1887871" data-ref-tag="" id="emailContact">
#         Contact Agent
#        </button>
#        <div id="dockerWishlist">
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="galleryBand">
#      <div class="wrapper">
#       <a class="mainImage galleryImage modalLink" data-media-index="0" data-media-type="image" href="#mediaGallery" style="background-image:url(https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-66071495_sd.jpg);" title="1.3 ha farm in Byrne Valley photo number 1">
#        <div class="galleryInfo">
#         <div class="wishlistButton" data-props='{"listingId":2366552,"listingType":1,"isOnWishlist":false}'>
#         </div>
#        </div>
#       </a>
#      </div>
#      <div class="listingStateHolder">
#       <div class="wrapper">
#       </div>
#      </div>
#     </div>
#     <div class="contentWhite listingInfo buttonBar">
#      <div class="wrapper row">
#       <div class="buttonsContainer">
#        <div class="mediaButtons">
#         <a class="mediaLink modalLink mediaPhotos" data-media-index="0" data-media-type="image" href="#mediaGallery" id="photosMediaLink" rel="nofollow">
#          Photos
#          <span>
#           5
#          </span>
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="contentWhite listingInfo">
#      <div class="topSection wrapper row">
#       <div class="topLeft">
#        <div class="marginedIn">
#         <div class="titleContainer">
#          <h1>
#           1.3 ha farm in Byrne Valley
#          </h1>
#          <h2 class="priceInfo">
#           <span class="detailsCurrencySymbol">
#            R
#           </span>
#           <span class="detailsPrice">
#            700 000
#           </span>
#          </h2>
#          <a class="noAddress " href="#bondCalculatorAnchor" id="canIAfford">
#           Can I afford this?
#          </a>
#          <div class="resultFeatures row noAddress">
#           <div class="feature">
#            <span>
#             2
#            </span>
#            Beds
#           </div>
#           <div class="feature">
#            <span>
#             1
#            </span>
#            Baths
#           </div>
#          </div>
#         </div>
#         <div class="mainFeatures row">
#          <div class="mainFeatureColumn">
#           <div class="mainFeature row ">
#            Floor Area
#            <span>
#             150 m²
#            </span>
#           </div>
#           <div class="mainFeature row ">
#            Land Area
#            <span>
#             1.3 ha
#            </span>
#           </div>
#          </div>
#          <div class="mainFeatureColumn">
#           <div class="mainFeature row ">
#            Rates
#            <span>
#             R 300
#            </span>
#           </div>
#          </div>
#         </div>
#         <div class="description">
#          <div class="seeMoreContainer">
#           <div id="expander">
#            <div id="descriptionParagraph">
#             <p>
#              A historic home in Byrne Valley.
#             </p>
#             <p>
#              A chance to own one of the first dwellings ever built in Byrne Valley.  This historic home with wonderful views over the countryside, is set on a manageable 1.3 ha (half a hectare is arable) with two bedrooms, a loft room, lounge, dining room (currently used as another bedroom), kitchen, and one bathroom.  It is constructed of shale with traditionally thick walls, and has a thatched roof with a combination of tiled and wooden floors.
#             </p>
#             <p>
#              A wonderful piece of history begging for someone to have the honor of restoring it to the original beauty, and more.  The location is ideal, as it is just outside of the village - which is a beautifully peaceful place as well.
#             </p>
#             <p>
#              The nearest town with all amenities is Richmond (17 kms) which has grocery stores, retail stores, food outlets, post office, schools and banks etc.
#             </p>
#            </div>
#           </div>
#           <a href="#" id="seeMore">
#            Read More
#            <span>
#            </span>
#           </a>
#          </div>
#         </div>
#         <div class="features">
#          <h3>
#           Key Property Features
#          </h3>
#          <div class="featureCols">
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue blueBack">
#              <span class="text">
#               1
#              </span>
#             </div>
#             <span class="attributeLabel">
#              Bathrooms
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue blueBack">
#              <span class="text">
#               2
#              </span>
#             </div>
#             <span class="attributeLabel">
#              Bedrooms
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue blueBack">
#              <span class="text">
#               1
#              </span>
#             </div>
#             <span class="attributeLabel">
#              Dining Areas
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue blueBack">
#              <span class="text">
#               1
#              </span>
#             </div>
#             <span class="attributeLabel">
#              Lounges
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue blueBack">
#              <span class="text">
#               1
#              </span>
#             </div>
#             <span class="attributeLabel">
#              Storeys
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue tick">
#             </div>
#             <span class="attributeLabel">
#              Fenced
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue tick">
#             </div>
#             <span class="attributeLabel">
#              Fireplace
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue tick">
#             </div>
#             <span class="attributeLabel">
#              Kitchen
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue tick">
#             </div>
#             <span class="attributeLabel">
#              Pets Allowed
#             </span>
#            </div>
#           </div>
#           <div class="featuresColumn">
#            <div class="attribute">
#             <div class="propAttrValue tick">
#             </div>
#             <span class="attributeLabel">
#              Scenic View
#             </span>
#            </div>
#           </div>
#          </div>
#         </div>
#         <p>
#          <a class="actionLink" data-account-holder-id="1887871" data-r="" data-ref-tag="" href="#" id="emailAgentLink">
#           Email the Agent
#          </a>
#          or request the agent
#          <a class="actionLink" data-ref-tag="" href="#" id="callMeBackLink">
#           Call You Back
#          </a>
#          should you require any further details.
#         </p>
#        </div>
#       </div>
#       <div class="topRight">
#        <div class="rightPositioning">
#         <div class="detailsContactCard" id="contactGallery" style="background-color:#121F49;border-width:1px;border-color:#101B41;color:#fff">
#          <div class="agentDetails swiper-container" data-bind="css:{numbersShown:!showNumbersButton(),showAll:displayAllContacts()}">
#           <div class="swiper-wrapper" data-bind="foreachInit:{name:'contactTemplate',data:contactCards}">
#            <div class="agent swiper-slide swiper-no-swiping" data-init="">
#             <a class="imageLink" data-bind="init, attr:{href:agentPageUrl}" href="/estate-agent/vanessa-foxon/1887871/?rt=">
#              <div class="agentImage">
#               <img alt="Vanessa Foxon" data-bind="init, attr:{src:agentImage, alt:contactName}, event:{error:function(data,event){removeBrokenImage(event);}}" src="https://prppublicstore.blob.core.windows.net/live-za-images/accountholders/1887871/image/633004935ddd4836bf7260c6f162ed43_ach.jpg"/>
#              </div>
#             </a>
#             <a class="contactName" data-bind="init:{contactName:'Vanessa Foxon', agentPageUrl:'/estate-agent/vanessa-foxon/1887871/?rt='}, attr:{href:agentPageUrl}, text:contactName" style="color:#fff;">
#              Vanessa Foxon
#             </a>
#             <div class="contactType" data-bind="init, text:contactType" style="color:#fff;">
#              Agent
#             </div>
#             <div class="telNos" data-bind="style:{visibility:hasNumbersShown() ? 'visible' : 'hidden'}, foreach:contactNumbers">
#              <div class="telNo">
#               <span data-bind="text:numberType" style="color:#fff;">
#               </span>
#               <a data-bind="attr:{href:'tel:' + phoneNumber.replace(/ /g,'')},
#                                               text:phoneNumber,
#                                               events:{click:function(data,event){cancelBubbling(event);},
#                                                       mousedown:function(data,event){cancelBubbling(event);},
#                                                       mousemove:function(data,event){cancelBubbling(event);}}" style="color:#fff;">
#               </a>
#              </div>
#             </div>
#             <input class="contactId" data-bind="init:{convert:parseInt},value:contactId" type="hidden" value="1887871"/>
#             <input class="showContactNumbers" data-bind="init, {field:canShowNumbers,value:true}, value:canShowNumbers" type="hidden" value="true"/>
#            </div>
#           </div>
#           <div class="telNos button" data-bind="css:{hideButton: !showNumbersButton()}" style="display:block;">
#            <button class="showTelNos eventShowNumber" data-bind="event:{
#                             click:function(data,event){showNumbers(event);},
#                             mouseover:function(data,event){showHoverColor('#707891',event)},
#                             mouseout:function(data,event){removeHoverColor(event);}
#                             }" style="background-color:#59627F;border:0;color:#fff" type="button">
#             <svg class="phoneIcon" viewbox="0 0 20 20" xmlns="http://www.w3.org/2000/svg">
#              <path d="M3.9 3.5l3.8 3.6L6 8.8l0 0c0.5 0.8 1.4 1.8 2.5 2.7 1.1 0.9 2.3 1.6 3.2 1.9l0 0 1.2-2.1 4.4 2.9L15 16.1l0 0c-1.6 0.5-4.7-0.8-7.7-3.1 -3-2.4-4.8-5.1-4.7-6.8l0 0L3.9 3.5z" fill="#fff">
#              </path>
#             </svg>
#             Show Phone No.
#            </button>
#           </div>
#          </div>
#          <div class="officeLogo">
#           <a href="/estate-agency/howick/3787?rt=">
#            <img alt="Dormehl Property Group-Howick" src="https://prppublicstore.blob.core.windows.net/live-za-images/offices/3787/image/ae38b7cec5234f148f4b2b7dd4585543_ola.jpg"/>
#           </a>
#          </div>
#         </div>
#         <div class="contactForm">
#          <div class="detailsContactFormContainer">
#           <h4>
#            Contact Agent
#           </h4>
#           <div class="formContainer">
#            <input data-val="true" data-val-number="The field ListingId must be a number." id="ListingId" name="ListingId" type="hidden" value="2366552"/>
#            <label>
#             Your Details
#            </label>
#            <div class="editDetails">
#             <div class="formControl">
#              <input data-bind="init, value:name,event:{focus:function(data,event){clearError('name',data,event);}}" name="Name" placeholder="your name" type="text"/>
#             </div>
#             <div class="formControl">
#              <input data-bind="init, value:email,event:{focus:function(data,event){clearError('email',data,event);}}" name="Email" placeholder="your email" type="email"/>
#             </div>
#             <div class="formControl">
#              <input data-bind="init, value:mobileNumber,event:{focus:function(data,event){clearError('mobileNumber',data,event);}}" name="MobileNumber" pattern="[0-9 ]*" placeholder="your mobile number" type="tel"/>
#             </div>
#            </div>
#            <label class="messageLabel" for="Message">
#             your message
#            </label>
#            <div class="formControl">
#             <textarea data-bind="init, value:message,event:{focus:function(data,event){clearError('message',data,event);}}" name="Message">Please contact me regarding this property.</textarea>
#            </div>
#            <div class="buttons">
#             <div class="buttonsHolder" data-bind="visible:(!isSending() &amp;&amp; !messageSent())">
#              <a class="orangeButton eventEmailSent" data-bind="click:function(data,event){sendMessage(event,'Email')}" href="#">
#               Email Agent
#              </a>
#              <a class="greenButton eventCallMeBack" data-bind="click:function(data,event){sendMessage(event,'CallMeBack')}" href="#">
#               Call Me Back
#              </a>
#             </div>
#             <div class="sending" data-bind="visible:isSending()">
#              Sending Message...
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="termsAndConditions">
#           By sending, you agree to Private Property's
#           <a href="/terms-and-conditions" target="_blank">
#            terms and conditions
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="hdThumbs">
#       <h4>
#        Photo Gallery
#       </h4>
#       <div class="imageGrid wrapper">
#        <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-66071495_mo.jpg" data-media-index="0" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#        </a>
#        <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-37461043_mo.jpg" data-media-index="1" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#        </a>
#        <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-69163842_mo.jpg" data-media-index="2" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#        </a>
#        <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-90390915_mo.jpg" data-media-index="3" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#        </a>
#        <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-60680521_mo.jpg" data-media-index="4" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#        </a>
#        <div class="miniContactCard swiper-container" id="miniContactCard" style="border-color:#121F49;">
#         <div class="swiper-wrapper">
#          <div class="swiper-slide">
#           <div class="agentImage">
#            <img alt="Vanessa Foxon" src="https://prppublicstore.blob.core.windows.net/live-za-images/accountholders/1887871/image/633004935ddd4836bf7260c6f162ed43_ach.jpg"/>
#           </div>
#           <div class="agentName">
#            <p>
#             Vanessa
#            </p>
#            <p>
#             Foxon
#            </p>
#           </div>
#          </div>
#         </div>
#         <button class="orangeButton " data-account-holder-id="1887871" data-ref-tag="" id="miniContactCardButton">
#          Contact Agent
#         </button>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="contentWhite bandMediumPadding">
#      <div class="wrapper row" id="">
#       <h2>
#        Share this Property
#       </h2>
#       <div class="shareListing row sales">
#        <a class="actionLink modalLink email" data-portalref="T479322" href="#shareListing">
#        </a>
#        <div class="socicons">
#         <a class="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dfacebook&amp;title=Explore+this+property+1.3+ha+farm+in+Byrne+Valley" target="_blank">
#         </a>
#         <a class="twitter" href="https://twitter.com/intent/tweet?text=Explore+this+property+1.3+ha+farm+in+Byrne+Valley+https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dtwitter+%40propertysa" target="_blank">
#         </a>
#         <a class="googlePlus" href="https://plus.google.com/share?url=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dgoogleplus" target="_blank">
#         </a>
#         <a class="pintrest" href="https://pinterest.com/pin/create/bookmarklet/?media=https%3a%2f%2fprppublicstore.blob.core.windows.net%2flive-za-images%2fproperty%2f552%2f33%2f2366552%2fimages%2fproperty-2366552-66071495_sd.jpg&amp;url=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dpinterest&amp;is_video=false&amp;description=Explore+this+property+1.3+ha+farm+in+Byrne+Valley" target="_blank">
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="contentGrey9 bandMediumPadding keyline">
#      <div id="bondCalculatorAnchor">
#      </div>
#      <div class="wrapper row">
#       <h2>
#        Need a Home Loan?
#       </h2>
#       <div class="calculatorContainer bondCalculator">
#        <div class="row">
#         <div class="formFields width50">
#          <form action="/Portal/Calculators/BondCalculator?purchasePrice=1200000" class="bondFormContainer" id="bondCalculatorForm" method="post">
#           <div class="formControl">
#            <div class="label positionLeft">
#             <label for="PurchasePrice">
#              Purchase Price
#             </label>
#            </div>
#            <div class="control">
#             <span class="prefix">
#              R
#             </span>
#             <input autocapitalize="off" autocomplete="off" autocorrect="off" class="calcValue calcField" data-val="true" data-val-length="Max length 12 characters" data-val-length-max="12" data-val-number="The field Purchase Price must be a number." data-val-required="Please enter the Purchase Price." id="PurchasePrice" maxlength="12" name="PurchasePrice" novalidate="novalidate" pattern="^\d([\s]*\d){1,22}$" type="number" value="700000"/>
#            </div>
#           </div>
#           <div class="formControl">
#            <div class="label positionLeft">
#             <label for="DepositAmount">
#              Deposit Amount
#             </label>
#            </div>
#            <div class="control">
#             <span class="prefix">
#              R
#             </span>
#             <input autocapitalize="off" autocomplete="off" autocorrect="off" class="calcValue calcField" data-val="true" data-val-length="Max length 12 characters" data-val-length-max="12" data-val-number="The field Deposit Amount must be a number." id="DepositAmount" maxlength="12" name="DepositAmount" novalidate="novalidate" pattern="^\d([\s]*\d){1,22}$" placeholder="70000" type="number" value=""/>
#             <input data-val="true" data-val-number="The field DefaultDepositAmount must be a number." id="DefaultDepositAmount" name="DefaultDepositAmount" type="hidden" value="70000"/>
#            </div>
#           </div>
# ...
#                 <label>
#                  Your Details
#                 </label>
#                 <div class="editDetails">
#                  <div class="formControl">
#                   <input data-bind="init, value:name,event:{focus:function(data,event){clearError('name',data,event);}}" name="Name" placeholder="your name" type="text"/>
#                  </div>
#                  <div class="formControl">
#                   <input data-bind="init, value:email,event:{focus:function(data,event){clearError('email',data,event);}}" name="Email" placeholder="your email" type="email"/>
#                  </div>
#                  <div class="formControl">
#                   <input data-bind="init, value:mobileNumber,event:{focus:function(data,event){clearError('mobileNumber',data,event);}}" name="MobileNumber" pattern="[0-9 ]*" placeholder="your mobile number" type="tel"/>
#                  </div>
#                 </div>
#                 <label class="messageLabel" for="Message">
#                  your message
#                 </label>
#                 <div class="formControl">
#                  <textarea data-bind="init, value:message,event:{focus:function(data,event){clearError('message',data,event);}}" name="Message">Please contact me regarding this property.</textarea>
#                 </div>
#                 <div class="buttons">
#                  <div class="buttonsHolder" data-bind="visible:(!isSending() &amp;&amp; !messageSent())">
#                   <a class="orangeButton eventEmailSent" data-bind="click:function(data,event){sendMessage(event,'Email')}" href="#">
#                    Email Agent
#                   </a>
#                   <a class="greenButton eventCallMeBack" data-bind="click:function(data,event){sendMessage(event,'CallMeBack')}" href="#">
#                    Call Me Back
#                   </a>
#                  </div>
#                  <div class="sending" data-bind="visible:isSending()">
#                   Sending Message...
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="termsAndConditions">
#                By sending, you agree to Private Property's
#                <a href="/terms-and-conditions" target="_blank">
#                 terms and conditions
#                </a>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#         <div class="swiper-slide swiper-no-swiping gallerySlide" data-bind="init:{index:6},click:function(data,event){$parent.changeSlides(event)}" data-init="">
#          <div data-bind="init:{mediaType:'mo'}" data-init="">
#           <div class="mortgageOriginatorSlide mo" data-advert-id="1" data-bind="stopBindings:true">
#            <h4>
#             Need a Home Loan?
#            </h4>
#            <div class="row slideContents">
#             <div class="width100">
#              <div class="moForm slideForm">
#               <h5>
#                Contact an
#                <strong>
#                 ooba Home Loans
#                </strong>
#                Consultant
#               </h5>
#               <fieldset>
#                <legend>
#                 Your Details
#                </legend>
#                <div class="formControl">
#                 <input data-bind="init, value:name, event:{focus:function(data,event){clearError('name',data,event);}}" id="name" name="name" placeholder="your name"/>
#                </div>
#                <div class="formControl">
#                 <input data-bind="init, value:email, event:{focus:function(data,event){clearError('email',data,event);}}" id="email" name="mail" placeholder="your email"/>
#                </div>
#                <div class="formControl">
#                 <input data-bind="init, value:mobileNumber, event:{focus:function(data,event){clearError('mobileNumber',data,event);}}" id="mobileNumber" name="mobileNumber" placeholder="your mobile number"/>
#                </div>
#                <div class="buttons">
#                 <button class="orangeButton" data-bind="click:function(data,event){submitForm(event);}, visible:(!isSending() &amp;&amp; !messageSent())">
#                  Apply for a Home Loan
#                 </button>
#                 <div class="messageSending" data-bind="visible:isSending()">
#                  Sending message...
#                 </div>
#                </div>
#               </fieldset>
#               <a class="findOutMore" href="/ooba" target="_blank">
#                Find out more about
#                <strong>
#                 ooba's financial services
#                </strong>
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="swiper-button-prev photoGalleryButtons">
#        <a class="mediaViewerPrev" href="#">
#        </a>
#       </div>
#       <div class="swiper-button-next photoGalleryButtons">
#        <a class="mediaViewerNext" href="#">
#        </a>
#       </div>
#      </div>
#      <div data-bind="visible:(currentMedia() === 'map')">
#       <div data-lat="0" data-lng="0" data-title="1.3 ha farm in Byrne Valley" id="mapContainer">
#       </div>
#      </div>
#     </div>
#     <div class="photoThumbs" data-bind="visible:showImageCount()">
#      <div class="thumbNav">
#       <!-- ko foreach:imageThumbs  -->
#       <div class="thumb" data-bind="css:getThumbCss($parent.activeIndex()),
#                                                     event:{
#                                                         click:function(data,event){$parent.slideTo(imageIndex);},
#                                                         mouseover:function(data,event){ if(mediaType !== 'video' &amp;&amp; mediaType !== 'vt'){$parent.showThumb(imageIndex, event);}},
#                                                         mouseout:function(data,event){if(mediaType !== 'video' &amp;&amp; mediaType !== 'vt'){$parent.hideThumb(imageIndex);}}
#                                                     },
#                                                     style:{backgroundColor:(mediaType !== 'image' &amp;&amp; mediaType !== 'floorPlan') ? '#ccc': ''}">
#        <span data-bind="text:thumbContent">
#        </span>
#        <!-- ko if: (mediaType === "image" || mediaType === "floorPlan") -->
#        <div class="thumbPreview" data-bind="event:{mouseover:function(data,event){$parent.showThumb(imageIndex, event);},
#                                                                 mouseout:function(data,event){$parent.hideThumb(imageIndex);}},
#                                                                 css:{showThumb:$parent.thumbIndex() === imageIndex}">
#         <div class="imgHolder">
#          <img data-bind="attr:{'data-src':thumbUrl}"/>
#         </div>
#         <span>
#         </span>
#        </div>
#        <!-- /ko -->
#        <!-- ko if: (mediaType === "mo") -->
#        <div class="thumbPreview" data-bind="event:{mouseover:function(data,event){$parent.showThumb(imageIndex);},
#                                                                 mouseout:function(data,event){$parent.hideThumb(imageIndex);}},
#                                                                 css:{showThumb:$parent.thumbIndex() === imageIndex}">
#         <div class="moThumb">
#          <p>
#           Apply for a Home Loan
#          </p>
#         </div>
#         <span>
#         </span>
#        </div>
#        <!-- /ko -->
#        <!-- ko if: (mediaType === "contact") -->
#        <div class="thumbPreview" data-bind="event:{mouseover:function(data,event){$parent.showThumb(imageIndex);},
#                                                                     mouseout:function(data,event){$parent.hideThumb(imageIndex);}},
#                                                              css:{showThumb:$parent.thumbIndex() === imageIndex}">
#         <div class="contactThumb">
#          <p>
#           Contact
#           <br/>
#           Agent
#          </p>
#         </div>
#         <span>
#         </span>
#        </div>
#        <!-- /ko -->
#       </div>
#       <!-- /ko -->
#       <div class="photoNav">
#       </div>
#      </div>
#     </div>
#    </div>
#    <script id="slideTemplate" type="text/ko-template">
#     <div class="swiper-slide swiper-no-swiping" data-bind="attr:{index:dataSwiperSlideIndex}">
#         <!-- ko if(mediaType === "image")-->
#         <div class="swiper-lazy slideImage"
#              data-bind="attr:{'data-background':mediaUrl,'data-media-type':mediaType}, css:slideClass"
#              style="background-image:url(/Content/Portal/Images/placeholder/pp-icon-loading-600x450.png);">
#             <div class="swiper-lazy-preloader swiper-lazy-preloader-black"></div>
#         </div>
#         <!--/ko-->
#         <!--ko if( mediaType === "floorPlan" )-->
#         <div class="swiper-lazy slideImage"
#              data-bind="attr:{'data-background':mediaUrl,'data-media-type':mediaType}"
#              style="background-image:url(/Content/Portal/Images/placeholder/pp-icon-loading-600x450.png);"></div>
#         <!--/ko-->
#         <!--ko if( mediaType === "video" ||  mediaType === "vt")-->
#         <div data-bind="attr:{dataSrc:mediaUrl, 'data-media-type':mediaType}"
#              data-is-loaded="false"
#              class="mediaFrame"></div>
#         <!--/ko-->
#     </div>
#    </script>
#   </section>
#   <footer>
#    <div class="footerInfo row">
#     <div class="footerCol">
#      <h3>
#       Property
#      </h3>
#      <ul>
#       <li>
#        <a href="/">
#         Property For Sale
#        </a>
#       </li>
#       <li>
#        <a href="/to-rent">
#         Property To Rent
#        </a>
#       </li>
#       <li>
#        <a href="/on-show/">
#         Property On Show
#        </a>
#       </li>
#       <li>
#        <a href="/developments/South-Africa/1.htm">
#         Developments
#        </a>
#       </li>
#       <li>
#        <a href="/commercial-properties-for-sale-in-south-africa">
#         Commercial Sales
#        </a>
#       </li>
#       <li>
#        <a href="/commercial-properties-to-rent-in-south-africa">
#         Commercial Rentals
#        </a>
#       </li>
#       <li>
#        <a href="/bank-sales.htm">
#         Bank Repossessions
#        </a>
#       </li>
#       <li>
#        <a href="/estate-agents-in-south-africa">
#         Find an Estate Agent
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footerCol">
#      <h3>
#       Advertise
#      </h3>
#      <ul>
#       <li>
#        <a href="/list-your-property/list-for-sale.htm">
#         List Your Property For Sale
#        </a>
#       </li>
#       <li>
#        <a href="/list-your-property/list-to-rent.htm">
#         List Your Property To Rent
#        </a>
#       </li>
#       <li>
#        <a href="/list-your-property/list-as-an-agent.htm">
#         For Estate Agents
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footerCol">
#      <h3>
#       Services
#      </h3>
#      <ul>
#       <li>
#        <a href="/advice">
#         Property Advice
#        </a>
#       </li>
#       <li>
#        <a href="/advice/agent-advice">
#         Agent Advice
#        </a>
#       </li>
#       <li>
#        <a href="/bond-calculator.htm?rt= bondcalcfooter">
#         Bond Calculator
#        </a>
#       </li>
#       <li>
#        <a href="/bond-affordability-calculator.htm?rt= affordabilitycalcfooter">
#         Affordability Calculator
#        </a>
#       </li>
#       <li>
#        <a href="/bridging_finance.htm">
#         Bridging Finance
#        </a>
#       </li>
#       <li>
#        <a href="/attorneys/list/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546">
#         Attorneys
#        </a>
#       </li>
#       <li>
#        <a href="/rebosa">
#         REBOSA
#        </a>
#       </li>
#      </ul>
#     </div>
#     <div class="footerCol">
#      <h3>
#       Media
#      </h3>
#      <ul>
#       <li>
#        <a href="/advice/news/">
#         Property News
#        </a>
#       </li>
#       <li>
#        <a href="/neighbourhoods">
#         Neighbourhoods
#        </a>
#       </li>
#      </ul>
#      <div class="socialMedia">
#       <a class="facebook" href="http://www.facebook.com/propertysa" target="_blank">
#       </a>
#       <a class="twitter" href="https://twitter.com/propertysa" target="_blank">
#       </a>
#       <a class="youtube" href="http://www.youtube.com/user/privatepropertySA" target="_blank">
#       </a>
#       <a class="googlePlus" href="http://plus.google.com/+privateproperty/posts" target="_blank">
#       </a>
#      </div>
#     </div>
#     <div class="footerCol">
#      <h3>
#       Company
#      </h3>
#      <ul>
#       <li>
#        <a href="/careers">
#         Careers
#        </a>
#       </li>
#       <li>
#        <a href="/ContactUs.aspx">
#         Contact Us
#        </a>
#       </li>
#       <li>
#        <a href="/terms-and-conditions">
#         Terms &amp; Conditions
#        </a>
#       </li>
#       <li>
#        <a href="/sa-womens-hockey">
#         Sponsorships
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="wrapper copyrightSponsor">
#     <div class="copyright">
#      Copyright © Private Property South Africa (Pty) Ltd. 1997 - 2017. All Rights Reserved.
#     </div>
#     <div class="sawHockey">
#      <span>
#       <img src="/Content/Portal/Images/externalmedia/SAHockey/footer/sawh-logo1.png"/>
#       Proud sponsor of the South African Women's Hockey Team.
#      </span>
#     </div>
#    </div>
#   </footer>
#   <div class="successMessage row" id="message">
#   </div>
#   <div aria-hidden="true" class="dialog" id="portalModal" role="dialog">
#   </div>
#   <div class="menuBackdrop" id="backdrop">
#   </div>
#   <div id="messageResponse">
#   </div>
#   <!--[if IE 8]>
#         <div style='clear: both; height: 112px; width:350px; padding:0; position: fixed; bottom: 0; left:0;z-index:10;'>
#             <a href="/Portal/Legacy/BrowserNotSupported" target="_blank">
#                 <img src="/Content/Portal/Images/legacy/browser-outdated-01.png" alt="Your browser is outdated" width="350" height="112" />
#             </a>
#         </div>
#     <![endif]-->
#   <script>
#    var portalContext = {"isMobile":false,"listingType":1,"pageType":0,"isMobileApp":false,"allowPreloader":true,"deviceId":"zKirYjh5akes7P1-Q6s96w","baseUrl":"https://www.privateproperty.co.za/","showSiteTakeOver":false,"showClientSideDebugging":false};
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/3.1.1/jquery.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/react/15.3.2/react.min.js">
#   </script>
#   <script src="https://cdnjs.cloudflare.com/ajax/libs/react/15.3.2/react-dom.min.js">
#   </script>
#   <script src="/external-scripts/modernizr-custom.js">
#   </script>
#   <script src="/bundles/site.9f8c585f586a1d26313b.bundle.js">
#   </script>
#   <script>
#    var pageContext = {"pageName":"detailsPage","pageParams":{"listingId":2366552,"portalRef":"T479322","accountHolderIds":[1887871],"mortgageOriginator":1,"hasHdContent":false,"isOnWishlist":false,"mobileAppShareText":"1.3 ha farm in Byrne Valley for sale (R700 000)","listingPrice":"700000","suburbName":"Byrne Valley","houseType":"farm","numBedrooms":2.0}}
#   </script>
#   <script src="/bundles/listing.87f5645fc205aa02b88c.bundle.js">
#   </script>
#   <script id="contactTemplate" type="text/ko-template">
#    <div class="agent swiper-slide swiper-no-swiping" data-template data-bind="attr:{dataContactId:contactId}">
#             <a data-bind="attr:{href:agentPageUrl}">
#                 <div class="agentImage">
#                     <img data-bind="attr:{src:agentImage,alt:agentName}" />
#                 </div>
#             </a>
#             <a data-bind="attr:{href:agentPageUrl},text:agentName" class="contactName" style=color:#fff;>
#             </a>
#             <div class="contactType" data-bind="text:contactType" style=color:#fff;></div>
#             <div class="telNos" data-bind="visible:hasNumbersShown, foreach:contactNumbers">
#                 <div class="telNo">
#                     <span data-bind="style:{color:$parent.textColor}, text:numberType"></span><a data-bind="attr:{href:'tel:' + phoneNumber}, text:phoneNumber, style:{color:$parent.textColor}"></a>
#                 </div>
#             </div>
#         </div>
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Encodings
#
# Beautiful Soup is generally pretty clever about finding the right encoding for a document. However, you can also specify the encoding by providing a `from_encoding` argument to the `BeautifulSoup` constructor.

# %% [markdown]
# ## Accessing the Document

# %% [markdown]
# During the parsing process the document is converted into a tree of objects attached to the `BeautifulSoup` object.

# %% [markdown]
# ### Tags
#
# Tags are attached to the `BeautifulSoup` object as attributes.

# %%
soup.h1
# Out:
# <h1>1.3 ha farm in Byrne Valley</h1>

# %%
type(soup.h1)
# Out:
# bs4.element.Tag

# %% [markdown]
# ### Tag Name
#
# Tags have a `name` property.

# %%
soup.h1.name
# Out:
# 'h1'

# %% [markdown]
# ### Tag Attributes

# %%
soup.p
# Out:
# <p class="title">1.3 ha farm in Byrne Valley</p>

# %% [markdown]
# Individual tag attributes can be accessed by treated the tag like a dictionary.

# %%
soup.p['class']
# Out:
# ['title']

# %% [markdown]
# This is a good place to use the `get()` method to handle the case where a particular attribute might not be present.
#
# Or you can retrieve the whole dictionary.

# %%
soup.p.attrs
# Out:
# {'class': ['title']}

# %% [markdown]
# Attributes are mutable.

# %%
soup.p['id'] = 'first_paragraph'
soup.p
# Out:
# <p class="title" id="first_paragraph">1.3 ha farm in Byrne Valley</p>

# %% [markdown]
# ### Strings
#
# Many tags contain textual content.

# %%
soup.h1.string
# Out:
# '1.3 ha farm in Byrne Valley'

# %% [markdown]
# These have a special type in Beautiful Soup.

# %%
type(soup.h1.string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# The `string` attribute is only available if a tag has no descendants.
#
# If there are multiple descendants then you can use the `strings` and `stripped_strings` attributes, both of which are iterators.

# %% [markdown]
# If you want to do further operations with such a string you should turn it into a normal Python string first, otherwise you'll be lumped with all of the overhead of the `BeautifulSoup` object.

# %%
h1 = str(soup.h1.string)
h1
# Out:
# '1.3 ha farm in Byrne Valley'

# %%
type(h1)
# Out:
# str

# %% [markdown]
# You can achieve the same result more directly with the `text` attribute. In general you'll probably end up using this more often than the `string` attribute.

# %%
soup.h1.text
# Out:
# '1.3 ha farm in Byrne Valley'

# %%
type(soup.h1.text)
# Out:
# str

# %% [markdown]
# ## Navigating the Document

# %% [markdown]
# As we've seen above, one way to navigate a document is simply to use tag names. These names can be nested indefinitely.

# %%
soup.section.div.p
# Out:
# <p class="title" id="first_paragraph">1.3 ha farm in Byrne Valley</p>

# %% [markdown]
# But this is rather inflexible because it will only give you the *first* occurrence.

# %% [markdown]
# ### Children and Descendants
#
# The `children` attribute is an iterator over a tag's *direct* children.

# %%
soup.header
# Out:
# <header>
# <div class="wrapper">
# <div class="row">
# <a class="logo" href="/"></a>
# <nav class="siteNav row" id="siteNav">
# <ul class="leftSide row searchVisible">
# <li class="navigation relativePosition">
# <a class="topMenu" href="#">For Sale</a>
# <div class="dropDown leftRelativeToNavigation">
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|7|3|10&amp;nostore=true" title="Property For Sale in Byrne Valley">
# <span class="menuTitle">All Property for Sale</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses For Sale in Byrne Valley">
# <span class="menuTitle">Houses For Sale</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments For Sale in Byrne Valley">
# <span class="menuTitle">Apartments For Sale</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes For Sale in Byrne Valley">
# <span class="menuTitle">Complexes For Sale</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a class="row" href="/on-show/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Property On Show">
# <span class="menuTitle">Property On Show</span><span class="desc">On Show properties across South Africa</span>
# </a>
# <a href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Property For Sale in Byrne Valley">
# <span class="menuTitle">Commercial Sales</span><span class="desc"> in Byrne Valley</span>
# </a>
# <hr/>
# <a href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
# <span class="menuTitle">Estate Agents</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a href="/developments/South-Africa/1.htm" title="New homes in secure developments">
# <span class="menuTitle">Developments</span><span class="desc"> New homes in secure developments</span>
# </a>
# <a class="row" href="/bank-sales.htm" title="Bank Sales &amp; Repos">
# <span class="menuTitle">Bank Sales &amp; Repos</span><span class="desc">Repossessed homes at low prices</span>
# </a>
# <hr/>
# <a class="row" href="/advice/property/buying-advice/3351" title="Advice for Buyers">
# <span class="menuTitle">Advice for Buyers</span><span class="desc">Expert advice on buying property</span>
# </a>
# <a class="row" href="/Portal/PropertyAlerts" title="Receive Email Alerts">
# <span class="menuTitle">Receive Email Alerts</span><span class="desc">Receive notifications on new Properties For Sale</span>
# </a>
# </div>
# </li>
# <li class="navigation relativePosition">
# <a class="topMenu" href="#">To Rent</a>
# <div class="dropDown leftRelativeToNavigation">
# <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|11|3|7&amp;nostore=true" title="Property To Rent in Byrne Valley">
# <span class="menuTitle">Property To Rent</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses To Rent in Byrne Valley">
# <span class="menuTitle">Houses To Rent</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments To Rent in Byrne Valley">
# <span class="menuTitle">Apartments To Rent</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes To Rent in Byrne Valley">
# <span class="menuTitle">Complexes To Rent</span><span class="desc"> in Byrne Valley</span>
# </a>
# <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
# <span class="menuTitle">Commercial Rentals</span><span class="desc"> in Byrne Valley</span>
# </a>
# <hr/>
# <a class="row" href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
# <span class="menuTitle">Estate Agents</span><span class="desc"> in Byrne Valley</span>
# </a>
# <hr/>
# <a class="row" href="/advice/property/tenant-advice/3353" title="Advice for Tenants">
# <span class="menuTitle">Advice for Tenants</span><span class="desc">Expert advice on renting a property</span>
# </a>
# <a class="row" href="/Portal/PropertyAlerts?listingType=Rentals" title="Receive Rental Email Alerts">
# <span class="menuTitle">Receive Email Alerts</span><span class="desc">Get notifications on new Property To Rent</span>
# </a>
# <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile">
# <span class="menuTitle">Tenant VIP Profile</span><span class="desc">Apply for unlimited rentals online with VIP from Ekaya</span>
# </a>
# </div>
# </li>
# <li class="navigation relativePosition">
# <a class="topMenu" href="#">Commercial</a>
# <div class="dropDown leftRelativeToNavigation">
# <a class="row" href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Sales in Byrne Valley">
# <span class="menuTitle widerTitle">Commercial Sales</span><span class="desc">in Byrne Valley</span>
# </a>
# <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
# <span class="menuTitle widerTitle">Commercial Rentals</span><span class="desc">in Byrne Valley</span>
# </a>
# <hr/>
# <a class="row" href="/Portal/PropertyAlerts" title="Recieve Commercial Email Alerts">
# <span class="menuTitle widerTitle">Receive Email Alerts</span><span class="desc">Receive notifications on new Commercial Property</span>
# </a>
# </div>
# </li>
# <li class="navigation">
# <a class="topMenu" href="#">Advice</a>
# <div class="dropDown rightRelativeToSiteNav">
# <a class="row" href="/advice" title="Advice Centre"><span class="menuTitle">Advice Centre</span><span class="desc">All your property related advice in one spot</span></a>
# <hr/>
# <a class="row" href="/advice/property" title="Property Advice"><span class="menuTitle">Property Advice</span><span class="desc">Insights for buyers, sellers, landlords and tenants</span></a>
# <a class="row" href="/advice/news" title="News"><span class="menuTitle">News</span><span class="desc">Breaking news in the SA property market</span></a>
# <a class="row" href="/advice/lifestyle" title="Lifestyle and Decor"><span class="menuTitle">Lifestyle and Decor</span><span class="desc">Handy maintenance, decor and DIY tips</span></a>
# <a class="row" href="/neighbourhoods" title="Neighbourhoods"><span class="menuTitle">Neighbourhoods</span><span class="desc">Get to know SA's best neighbourhoods</span></a>
# <a class="row" href="/advice/property-tv" title="Property TV"><span class="menuTitle">Property TV</span><span class="desc">Catch up on our TV show appearances</span></a>
# <a class="row" href="/advice/agent-advice" title="Agent Advice"><span class="menuTitle">Agent Advice</span><span class="desc">Great advice for industry professionals</span></a>
# <hr/>
# <a class="row" href="http://eepurl.com/PnGeL" target="_blank" title="Newsletter"><span class="menuTitle">Newsletter</span><span class="desc">General and investment advice on the property market</span></a>
# </div>
# </li>
# <li class="navigation">
# <a class="topMenu" href="#">Services</a>
# <div class="dropDown rightRelativeToSiteNav">
# <a class="row" href="/list-your-property/list-for-sale.htm" title="Sell Your Property"><span class="menuTitle widerTitle">Sell Your Property</span><span class="desc">Advertise your property to millions of interested buyers</span></a>
# <a class="row" href="/list-your-property/list-to-rent.htm" title="Let Your Property"><span class="menuTitle widerTitle">Rent Your Property</span><span class="desc"><em class="greenText">Free to advertise</em> on SA's largest rental platform</span></a>
# <hr/>
# <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile"><span class="menuTitle widerTitle">Tenant VIP Profile</span><span class="desc">Apply for unlimited rentals online with VIP from Ekaya</span></a>
# <a class="row" href="/advice/property/articles/ekaya-vip-a-smart-solution-for-smart-landlords/5781" title="Tenant Vetting"><span class="menuTitle widerTitle">Tenant Vetting</span><span class="desc">Vet all your potential tenants with VIP from Ekaya</span></a>
# <hr/>
# <a class="row" href="/bond-calculator.htm?rt=bondcalcmenu" title="Bond Repayments Calculator"><span class="menuTitle widerTitle">Bond Calculator</span><span class="desc">Calculate the monthly repayments on your bond</span></a>
# <a class="row" href="/bond-affordability-calculator.htm?rt=affordabilitycalcmenu" title="Bond Affordability Calculator"><span class="menuTitle widerTitle">Affordability Calculator</span><span class="desc">Calculate the maximum bond you can afford</span></a>
# <hr/>
# <a class="row" href="/ooba">
# <span class="menuTitle widerTitle">ooba Home Loans</span>
# <span class="desc">Get prequalified for a home loan today.</span>
# </a>
# <a class="row" href="/betterbond">
# <span class="menuTitle widerTitle">Better Bond Home Loans</span>
# <span class="desc">We get you preapproved so you know what you can afford.</span>
# </a>
# <a class="row" href="/bridging_finance.htm" title="Bridging Finance"><span class="menuTitle widerTitle">Bridging Finance</span><span class="desc">Access your funds immediately after selling your property</span></a>
# <hr/>
# <a class="row" href="/attorneys/list/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Attorney Database"><span class="menuTitle widerTitle">Attorney Directory</span><span class="desc">Find a good attorney in your area</span></a>
# <a class="row" href="/estate-agents-in-south-africa" title="Find an Agent"><span class="menuTitle widerTitle">Find an Agent</span><span class="desc">Find a good estate agent in your area</span></a>
# <a class="row" href="/list-your-property/list-as-an-agent.htm" title="Advertise Your Agency"><span class="menuTitle widerTitle">Advertise Your Agency</span><span class="desc">Join other top estate agencies on Private Property</span></a>
# <a class="row" href="/rebosa" title="Rebosa"><span class="menuTitle widerTitle">REBOSA</span><span class="desc">Private Property is the exclusive portal partner to REBOSA</span></a>
# </div>
# </li>
# </ul>
# <ul class="rightSide row">
# <li class="search navigation">
# <a class="topMenu" href="#" id="menuSearch">Search</a>
# <div class="dropDown rightRelativeToSiteNav">
# <div id="menuSeachBox"></div>
# <div class="suggestions row">
# <div class="nearby">
# <div class="searchHeading">Nearby Suburbs and Areas</div>
# <ul id="nearbyShapes">
# <li>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/richmond/88" title="Richmond">Richmond</a>
# </li>
# <li>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/ixopo/1463" title="Ixopo">Ixopo</a>
# </li>
# <li>
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/creighton/1462" title="Creighton">Creighton</a>
# </li>
# </ul>
# </div>
# <div class="recentSearches">
# <div class="searchHeading">Recent Searches</div>
# <ul id="recentSearches">
# </ul>
# </div>
# </div>
# </div>
# </li>
# <li class="login">
# <a class="topMenu" href="#" id="loginSignup">
# <div id="loginIcon"></div>
#                     Sign In
#             </a>
# <div class="dropDown rightRelativeToSiteNav">
# <a class="modalLink" href="#login" title="Sign In"><span class="menuTitle narrowerTitle">Sign In</span><span class="desc">Have an existing account?</span></a>
# <a class="modalLink" href="#signup" title="Register"><span class="menuTitle narrowerTitle">Register</span><span class="desc">Create a new account</span></a>
# <hr/>
# <a class="menuTitle" href="/Portal/AccountHolders/ForgotPassword?returnUrl=%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322" title="Forgot Your Password"><span class="menuTitle">Forgot Your Password</span></a>
# </div>
# </li>
# </ul>
# </nav>
# </div>
# <div class="breadcrumbContainer ">
# <div class="breadcrumb">
# <a class="previousPage" href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" id="backButton" title="Byrne Valley">Back to <span class="backlink">Byrne Valley</span></a>
# <span class="mainCrumbs">
# <a href="/">Property For Sale</a>
# <span class="crumbSeparator"> &gt; </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/for-sale/kwazulu-natal/2" itemprop="url"><span itemprop="title">KwaZulu Natal</span></a>
# <span class="crumbSeparator"> &gt; </span>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/for-sale/kwazulu-natal/drakensberg/2530" itemprop="url"><span itemprop="title">Drakensberg</span></a>
# <span class="crumbSeparator"> &gt; </span>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/2533" itemprop="url"><span itemprop="title">Richmond and surrounds</span></a>
# <span class="crumbSeparator"> &gt; </span>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" itemprop="url"><span itemprop="title">Byrne Valley</span></a>
# <span class="crumbSeparator"> &gt; </span>
# </span>
# <span itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
# <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T479322" itemprop="url"><span itemprop="title">T479322</span></a>
# </span>
# </span>
# </div>
# </div>
# </div>
# </header>

# %% [markdown]
# The `children` attribute is an iterator over children.

# %%
len(list(soup.header.children))
# Out:
# 3

# %% [markdown]
# The `descendants` attribute is an iterator over *all* descendants.

# %%
len(list(soup.header.descendants))
# Out:
# 549

# %% [markdown]
# ### Parent and Ancestors
#
# You can navigate up the tree using the `parent` attribute.

# %%
soup.section.div.p.parent
# Out:
# <div class="listingInfo">
# <p class="title" id="first_paragraph">1.3 ha farm in Byrne Valley</p>
# <p class="price">
# <span class="detailsCurrencySymbol">R</span>
# <span class="detailsPrice">700 000</span>
# </p>
# </div>

# %% [markdown]
# The `parents` attribute will iterate from the immediate parent all the way up to the top of the tree.

# %% [markdown]
# ### Siblings
#
# A tag's siblings can be accessed with the `next_sibling` and `previous_sibling` attributes. Siblings are often simply strings rather than tags.

# %%
soup.section.div.p.next_sibling
# Out:
# '\n'

# %% [markdown]
# The `next_siblings` and `previous_siblings` attributes are iterators over siblings.

# %%
for sibling in soup.section.div.p.next_siblings:
    print(repr(sibling))
# Out:
# '\n'
# <p class="price">
# <span class="detailsCurrencySymbol">R</span>
# <span class="detailsPrice">700 000</span>
# </p>
# '\n'

# %% [markdown]
# ## Searching the Document

# %% [markdown]
# You can search a document using
#
# - a tag's name or
# - a tag's attributes.
#
# These can also be combined to generate complex queries.

# %% [markdown]
# The `find_all()` method has the following parameters:
#
# - `name` (tag name),
# - `attrs`: (tag attributes),
# - `recursive`,
# - `text`,
# - `limit` and
# - `**kwargs` (other keyword arguments).
#
# This will locate all tags which match the criteria.

# %% [markdown]
# If you only want a single match then it's better to simply use the `find()` method, which accepts the same arguments as `find_all()`.

# %% [markdown]
# ### Seach by Tag Name
#
# Search for tags by name.

# %%
soup.find_all('a')
# Out:
# [<a class="logo" href="/"></a>,
#  <a class="topMenu" href="#">For Sale</a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|7|3|10&amp;nostore=true" title="Property For Sale in Byrne Valley">
#  <span class="menuTitle">All Property for Sale</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses For Sale in Byrne Valley">
#  <span class="menuTitle">Houses For Sale</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments For Sale in Byrne Valley">
#  <span class="menuTitle">Apartments For Sale</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes For Sale in Byrne Valley">
#  <span class="menuTitle">Complexes For Sale</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/on-show/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Property On Show">
#  <span class="menuTitle">Property On Show</span><span class="desc">On Show properties across South Africa</span>
#  </a>,
#  <a href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Property For Sale in Byrne Valley">
#  <span class="menuTitle">Commercial Sales</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
#  <span class="menuTitle">Estate Agents</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a href="/developments/South-Africa/1.htm" title="New homes in secure developments">
#  <span class="menuTitle">Developments</span><span class="desc"> New homes in secure developments</span>
#  </a>,
#  <a class="row" href="/bank-sales.htm" title="Bank Sales &amp; Repos">
#  <span class="menuTitle">Bank Sales &amp; Repos</span><span class="desc">Repossessed homes at low prices</span>
#  </a>,
#  <a class="row" href="/advice/property/buying-advice/3351" title="Advice for Buyers">
#  <span class="menuTitle">Advice for Buyers</span><span class="desc">Expert advice on buying property</span>
#  </a>,
#  <a class="row" href="/Portal/PropertyAlerts" title="Receive Email Alerts">
#  <span class="menuTitle">Receive Email Alerts</span><span class="desc">Receive notifications on new Properties For Sale</span>
#  </a>,
#  <a class="topMenu" href="#">To Rent</a>,
#  <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0|1|2|11|3|7&amp;nostore=true" title="Property To Rent in Byrne Valley">
#  <span class="menuTitle">Property To Rent</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=0&amp;nostore=true" title="Houses To Rent in Byrne Valley">
#  <span class="menuTitle">Houses To Rent</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=1&amp;nostore=true" title="Apartments To Rent in Byrne Valley">
#  <span class="menuTitle">Apartments To Rent</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/to-rent/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546?propertyTypes=2&amp;nostore=true" title="Complexes To Rent in Byrne Valley">
#  <span class="menuTitle">Complexes To Rent</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
#  <span class="menuTitle">Commercial Rentals</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/estate-agents/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Estate Agents in Byrne Valley">
#  <span class="menuTitle">Estate Agents</span><span class="desc"> in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/advice/property/tenant-advice/3353" title="Advice for Tenants">
#  <span class="menuTitle">Advice for Tenants</span><span class="desc">Expert advice on renting a property</span>
#  </a>,
#  <a class="row" href="/Portal/PropertyAlerts?listingType=Rentals" title="Receive Rental Email Alerts">
#  <span class="menuTitle">Receive Email Alerts</span><span class="desc">Get notifications on new Property To Rent</span>
#  </a>,
#  <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile">
#  <span class="menuTitle">Tenant VIP Profile</span><span class="desc">Apply for unlimited rentals online with VIP from Ekaya</span>
#  </a>,
#  <a class="topMenu" href="#">Commercial</a>,
#  <a class="row" href="/commercial-sales/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Sales in Byrne Valley">
#  <span class="menuTitle widerTitle">Commercial Sales</span><span class="desc">in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/commercial-rentals/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Commercial Rentals in Byrne Valley">
#  <span class="menuTitle widerTitle">Commercial Rentals</span><span class="desc">in Byrne Valley</span>
#  </a>,
#  <a class="row" href="/Portal/PropertyAlerts" title="Recieve Commercial Email Alerts">
#  <span class="menuTitle widerTitle">Receive Email Alerts</span><span class="desc">Receive notifications on new Commercial Property</span>
#  </a>,
#  <a class="topMenu" href="#">Advice</a>,
#  <a class="row" href="/advice" title="Advice Centre"><span class="menuTitle">Advice Centre</span><span class="desc">All your property related advice in one spot</span></a>,
#  <a class="row" href="/advice/property" title="Property Advice"><span class="menuTitle">Property Advice</span><span class="desc">Insights for buyers, sellers, landlords and tenants</span></a>,
#  <a class="row" href="/advice/news" title="News"><span class="menuTitle">News</span><span class="desc">Breaking news in the SA property market</span></a>,
#  <a class="row" href="/advice/lifestyle" title="Lifestyle and Decor"><span class="menuTitle">Lifestyle and Decor</span><span class="desc">Handy maintenance, decor and DIY tips</span></a>,
#  <a class="row" href="/neighbourhoods" title="Neighbourhoods"><span class="menuTitle">Neighbourhoods</span><span class="desc">Get to know SA's best neighbourhoods</span></a>,
#  <a class="row" href="/advice/property-tv" title="Property TV"><span class="menuTitle">Property TV</span><span class="desc">Catch up on our TV show appearances</span></a>,
#  <a class="row" href="/advice/agent-advice" title="Agent Advice"><span class="menuTitle">Agent Advice</span><span class="desc">Great advice for industry professionals</span></a>,
#  <a class="row" href="http://eepurl.com/PnGeL" target="_blank" title="Newsletter"><span class="menuTitle">Newsletter</span><span class="desc">General and investment advice on the property market</span></a>,
#  <a class="topMenu" href="#">Services</a>,
#  <a class="row" href="/list-your-property/list-for-sale.htm" title="Sell Your Property"><span class="menuTitle widerTitle">Sell Your Property</span><span class="desc">Advertise your property to millions of interested buyers</span></a>,
#  <a class="row" href="/list-your-property/list-to-rent.htm" title="Let Your Property"><span class="menuTitle widerTitle">Rent Your Property</span><span class="desc"><em class="greenText">Free to advertise</em> on SA's largest rental platform</span></a>,
#  <a class="row" href="/advice/property/articles/tenants-stand-out-from-the-crowd-with-ekaya-vip/5780" title="Tenant VIP Profile"><span class="menuTitle widerTitle">Tenant VIP Profile</span><span class="desc">Apply for unlimited rentals online with VIP from Ekaya</span></a>,
#  <a class="row" href="/advice/property/articles/ekaya-vip-a-smart-solution-for-smart-landlords/5781" title="Tenant Vetting"><span class="menuTitle widerTitle">Tenant Vetting</span><span class="desc">Vet all your potential tenants with VIP from Ekaya</span></a>,
#  <a class="row" href="/bond-calculator.htm?rt=bondcalcmenu" title="Bond Repayments Calculator"><span class="menuTitle widerTitle">Bond Calculator</span><span class="desc">Calculate the monthly repayments on your bond</span></a>,
#  <a class="row" href="/bond-affordability-calculator.htm?rt=affordabilitycalcmenu" title="Bond Affordability Calculator"><span class="menuTitle widerTitle">Affordability Calculator</span><span class="desc">Calculate the maximum bond you can afford</span></a>,
#  <a class="row" href="/ooba">
#  <span class="menuTitle widerTitle">ooba Home Loans</span>
#  <span class="desc">Get prequalified for a home loan today.</span>
#  </a>,
#  <a class="row" href="/betterbond">
#  <span class="menuTitle widerTitle">Better Bond Home Loans</span>
#  <span class="desc">We get you preapproved so you know what you can afford.</span>
#  </a>,
#  <a class="row" href="/bridging_finance.htm" title="Bridging Finance"><span class="menuTitle widerTitle">Bridging Finance</span><span class="desc">Access your funds immediately after selling your property</span></a>,
#  <a class="row" href="/attorneys/list/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" title="Attorney Database"><span class="menuTitle widerTitle">Attorney Directory</span><span class="desc">Find a good attorney in your area</span></a>,
#  <a class="row" href="/estate-agents-in-south-africa" title="Find an Agent"><span class="menuTitle widerTitle">Find an Agent</span><span class="desc">Find a good estate agent in your area</span></a>,
#  <a class="row" href="/list-your-property/list-as-an-agent.htm" title="Advertise Your Agency"><span class="menuTitle widerTitle">Advertise Your Agency</span><span class="desc">Join other top estate agencies on Private Property</span></a>,
#  <a class="row" href="/rebosa" title="Rebosa"><span class="menuTitle widerTitle">REBOSA</span><span class="desc">Private Property is the exclusive portal partner to REBOSA</span></a>,
#  <a class="topMenu" href="#" id="menuSearch">Search</a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/richmond/88" title="Richmond">Richmond</a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/ixopo/1463" title="Ixopo">Ixopo</a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/creighton/1462" title="Creighton">Creighton</a>,
#  <a class="topMenu" href="#" id="loginSignup">
#  <div id="loginIcon"></div>
#                      Sign In
#              </a>,
#  <a class="modalLink" href="#login" title="Sign In"><span class="menuTitle narrowerTitle">Sign In</span><span class="desc">Have an existing account?</span></a>,
#  <a class="modalLink" href="#signup" title="Register"><span class="menuTitle narrowerTitle">Register</span><span class="desc">Create a new account</span></a>,
#  <a class="menuTitle" href="/Portal/AccountHolders/ForgotPassword?returnUrl=%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322" title="Forgot Your Password"><span class="menuTitle">Forgot Your Password</span></a>,
#  <a class="previousPage" href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" id="backButton" title="Byrne Valley">Back to <span class="backlink">Byrne Valley</span></a>,
#  <a href="/">Property For Sale</a>,
#  <a href="/for-sale/kwazulu-natal/2" itemprop="url"><span itemprop="title">KwaZulu Natal</span></a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/2530" itemprop="url"><span itemprop="title">Drakensberg</span></a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/2533" itemprop="url"><span itemprop="title">Richmond and surrounds</span></a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546" itemprop="url"><span itemprop="title">Byrne Valley</span></a>,
#  <a href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T479322" itemprop="url"><span itemprop="title">T479322</span></a>,
#  <a class="mainImage galleryImage modalLink" data-media-index="0" data-media-type="image" href="#mediaGallery" style="background-image:url(https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-66071495_sd.jpg);" title="1.3 ha farm in Byrne Valley photo number 1">
#  <div class="galleryInfo">
#  <div class="wishlistButton" data-props='{"listingId":2366552,"listingType":1,"isOnWishlist":false}'></div>
#  </div>
#  </a>,
#  <a class="mediaLink modalLink mediaPhotos" data-media-index="0" data-media-type="image" href="#mediaGallery" id="photosMediaLink" rel="nofollow">Photos <span>5</span></a>,
#  <a class="noAddress " href="#bondCalculatorAnchor" id="canIAfford">Can I afford this?</a>,
#  <a href="#" id="seeMore">Read More<span></span></a>,
#  <a class="actionLink" data-account-holder-id="1887871" data-r="" data-ref-tag="" href="#" id="emailAgentLink">Email the Agent</a>,
#  <a class="actionLink" data-ref-tag="" href="#" id="callMeBackLink">Call You Back</a>,
#  <a class="imageLink" data-bind="init, attr:{href:agentPageUrl}" href="/estate-agent/vanessa-foxon/1887871/?rt=">
#  <div class="agentImage">
#  <img alt="Vanessa Foxon" data-bind="init, attr:{src:agentImage, alt:contactName}, event:{error:function(data,event){removeBrokenImage(event);}}" src="https://prppublicstore.blob.core.windows.net/live-za-images/accountholders/1887871/image/633004935ddd4836bf7260c6f162ed43_ach.jpg"/>
#  </div>
#  </a>,
#  <a class="contactName" data-bind="init:{contactName:'Vanessa Foxon', agentPageUrl:'/estate-agent/vanessa-foxon/1887871/?rt='}, attr:{href:agentPageUrl}, text:contactName" style="color:#fff;">
#                              Vanessa Foxon
#                          </a>,
#  <a data-bind="attr:{href:'tel:' + phoneNumber.replace(/ /g,'')},
#                                                text:phoneNumber,
#                                                events:{click:function(data,event){cancelBubbling(event);},
#                                                        mousedown:function(data,event){cancelBubbling(event);},
#                                                        mousemove:function(data,event){cancelBubbling(event);}}" style="color:#fff;"></a>,
#  <a href="/estate-agency/howick/3787?rt=">
#  <img alt="Dormehl Property Group-Howick" src="https://prppublicstore.blob.core.windows.net/live-za-images/offices/3787/image/ae38b7cec5234f148f4b2b7dd4585543_ola.jpg"/>
#  </a>,
#  <a class="orangeButton eventEmailSent" data-bind="click:function(data,event){sendMessage(event,'Email')}" href="#">Email Agent</a>,
#  <a class="greenButton eventCallMeBack" data-bind="click:function(data,event){sendMessage(event,'CallMeBack')}" href="#">Call Me Back</a>,
#  <a href="/terms-and-conditions" target="_blank">terms and conditions</a>,
#  <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-66071495_mo.jpg" data-media-index="0" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#  </a>,
#  <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-37461043_mo.jpg" data-media-index="1" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#  </a>,
#  <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-69163842_mo.jpg" data-media-index="2" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#  </a>,
#  <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-90390915_mo.jpg" data-media-index="3" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#  </a>,
#  <a class="gridImage modalLink lazyLoad" data-background="https://prppublicstore.blob.core.windows.net/live-za-images/property/552/33/2366552/images/property-2366552-60680521_mo.jpg" data-media-index="4" data-media-type="image" href="#mediaGallery" style="background-image:url(/Content/Portal/images/placeholder/pp-icon-loading-320x200.png);">
#  </a>,
#  <a class="actionLink modalLink email" data-portalref="T479322" href="#shareListing"> </a>,
#  <a class="facebook" href="https://www.facebook.com/sharer/sharer.php?u=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dfacebook&amp;title=Explore+this+property+1.3+ha+farm+in+Byrne+Valley" target="_blank"></a>,
#  <a class="twitter" href="https://twitter.com/intent/tweet?text=Explore+this+property+1.3+ha+farm+in+Byrne+Valley+https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dtwitter+%40propertysa" target="_blank"></a>,
#  <a class="googlePlus" href="https://plus.google.com/share?url=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dgoogleplus" target="_blank"></a>,
#  <a class="pintrest" href="https://pinterest.com/pin/create/bookmarklet/?media=https%3a%2f%2fprppublicstore.blob.core.windows.net%2flive-za-images%2fproperty%2f552%2f33%2f2366552%2fimages%2fproperty-2366552-66071495_sd.jpg&amp;url=https%3a%2f%2fwww.privateproperty.co.za%2ffor-sale%2fkwazulu-natal%2fdrakensberg%2frichmond-and-surrounds%2fbyrne-valley%2fT479322%3f%26rt%3dpinterest&amp;is_video=false&amp;description=Explore+this+property+1.3+ha+farm+in+Byrne+Valley" target="_blank"></a>,
#  <a class="modalLink" data-mortgage-banner-type="Ooba" data-rt="listing_bondcalc" href="#affordabilityCalc">Can I afford this?</a>,
#  <a class="applyForHomeLoan modalLink" data-lead-source="ListingBillboard" data-listing-id="2366552" data-mortgage-originator="Ooba" data-view="Details" href="#moDialog" id="applyForHomeLoan">
#                          Apply for pre-approval
#                      </a>,
#  <a class="closeModal" href="#" id="dialogClose"></a>,
#  <a class="neighbourhoodListingCard materialCard" href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T764620?rt=Listing_SimilarProperty">
#  <div class="imageContainer">
#  <img alt="8.1 ha farm in Byrne Valley" class="image lazyLoad" data-original="https://prppublicstore.blob.core.windows.net/live-za-images/property/1465/44/2789465/images/property-2789465-90957597_mo.jpg" src="/Content/Portal/images/placeholder/pp-icon-loading-320x200.png"/>
#  <div class="priceContainer">
#  <span class="price">R 630 000</span>
#  </div>
#  </div>
#  <div class="informationContainer">
#  <div class="title">8.1 ha farm in Byrne Valley</div>
#  <div class="features">
#  <div class="numberOfBeds">2 <div class="icon bedIcon"></div> </div>
#  <div class="numberOfBaths">2 <div class="icon bathIcon"></div> </div>
#  <div class="numberOfParking">1 <div class="icon parkingIcon"></div> </div>
#  </div>
#  </div>
#  </a>,
#  <a class="neighbourhoodListingCard materialCard" href="/for-sale/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/T709644?rt=Listing_SimilarProperty">
#  <div class="imageContainer">
#  <img alt="5 Bedroom House in Byrne Valley" class="image lazyLoad" data-original="https://prppublicstore.blob.core.windows.net/live-za-images/property/1369/3/2707369/images/property-2707369-42804060_mo.jpg" src="/Content/Portal/images/placeholder/pp-icon-loading-320x200.png"/>
#  <div class="priceContainer">
#  <span class="price">R 695 000</span>
#  </div>
#  </div>
#  <div class="informationContainer">
#  <div class="title">5 Bedroom House in Byrne Valley</div>
#  <div class="features">
#  <div class="numberOfBeds">5 <div class="icon bedIcon"></div> </div>
#  <div class="numberOfBaths">3 <div class="icon bathIcon"></div> </div>
#  <div class="numberOfParking">0 <div class="icon parkingIcon"></div> </div>
#  </div>
#  </div>
#  </a>,
#  <a class="modalLink" data-portalref="T479322" href="#listingScore" id="listingScore">
#                                          View property score
#                                      </a>,
#  <a class="printListing" href="/Portal/Listing/DetailsPrint?portalRef=T479322" target="_blank" title="">Print property details</a>,
#  <a class="modalLink" data-portalref="T479322" href="#reportListing" id="reportListing">
#                                  Report this property
#                              </a>,
#  <a class="mediaPhotos" data-bind="click:function(){changeMedia('image')},css:{selected:(currentMedia() === 'image' || currentMedia() === 'contact'
#                     || currentMedia() === 'mo')}">Photos <span>5</span></a>,
#  <a class="closeButton" data-bind="click:function(data,e){e.preventDefault();closeGallery();}"></a>,
#  <a class="imageLink" data-bind="init, attr:{href:agentPageUrl}" href="/estate-agent/vanessa-foxon/1887871/?rt=">
#  <div class="agentImage">
#  <img alt="Vanessa Foxon" data-bind="init, attr:{src:agentImage, alt:contactName}, event:{error:function(data,event){removeBrokenImage(event);}}" src="https://prppublicstore.blob.core.windows.net/live-za-images/accountholders/1887871/image/633004935ddd4836bf7260c6f162ed43_ach.jpg"/>
#  </div>
#  </a>,
#  <a class="contactName" data-bind="init:{contactName:'Vanessa Foxon', agentPageUrl:'/estate-agent/vanessa-foxon/1887871/?rt='}, attr:{href:agentPageUrl}, text:contactName" style="color:#fff;">
#                              Vanessa Foxon
#                          </a>,
#  <a data-bind="attr:{href:'tel:' + phoneNumber.replace(/ /g,'')},
#                                                text:phoneNumber,
#                                                events:{click:function(data,event){cancelBubbling(event);},
#                                                        mousedown:function(data,event){cancelBubbling(event);},
#                                                        mousemove:function(data,event){cancelBubbling(event);}}" style="color:#fff;"></a>,
#  <a href="/estate-agency/howick/3787?rt=">
#  <img alt="Dormehl Property Group-Howick" src="https://prppublicstore.blob.core.windows.net/live-za-images/offices/3787/image/ae38b7cec5234f148f4b2b7dd4585543_ola.jpg"/>
#  </a>,
#  <a class="orangeButton eventEmailSent" data-bind="click:function(data,event){sendMessage(event,'Email')}" href="#">Email Agent</a>,
#  <a class="greenButton eventCallMeBack" data-bind="click:function(data,event){sendMessage(event,'CallMeBack')}" href="#">Call Me Back</a>,
#  <a href="/terms-and-conditions" target="_blank">terms and conditions</a>,
#  <a class="findOutMore" href="/ooba" target="_blank">Find out more about <strong>ooba's financial services</strong></a>,
#  <a class="mediaViewerPrev" href="#"></a>,
#  <a class="mediaViewerNext" href="#"></a>,
#  <a href="/">Property For Sale</a>,
#  <a href="/to-rent">Property To Rent</a>,
#  <a href="/on-show/">Property On Show</a>,
#  <a href="/developments/South-Africa/1.htm">Developments</a>,
#  <a href="/commercial-properties-for-sale-in-south-africa">Commercial Sales</a>,
#  <a href="/commercial-properties-to-rent-in-south-africa">Commercial Rentals</a>,
#  <a href="/bank-sales.htm">Bank Repossessions</a>,
#  <a href="/estate-agents-in-south-africa">Find an Estate Agent</a>,
#  <a href="/list-your-property/list-for-sale.htm">List Your Property For Sale</a>,
#  <a href="/list-your-property/list-to-rent.htm">List Your Property To Rent</a>,
#  <a href="/list-your-property/list-as-an-agent.htm">For Estate Agents</a>,
#  <a href="/advice">Property Advice</a>,
#  <a href="/advice/agent-advice">Agent Advice</a>,
#  <a href="/bond-calculator.htm?rt= bondcalcfooter">Bond Calculator</a>,
#  <a href="/bond-affordability-calculator.htm?rt= affordabilitycalcfooter">Affordability Calculator</a>,
#  <a href="/bridging_finance.htm">Bridging Finance</a>,
#  <a href="/attorneys/list/kwazulu-natal/drakensberg/richmond-and-surrounds/byrne-valley/2546">Attorneys</a>,
#  <a href="/rebosa">REBOSA</a>,
#  <a href="/advice/news/">Property News</a>,
#  <a href="/neighbourhoods">Neighbourhoods</a>,
#  <a class="facebook" href="http://www.facebook.com/propertysa" target="_blank"></a>,
#  <a class="twitter" href="https://twitter.com/propertysa" target="_blank"></a>,
#  <a class="youtube" href="http://www.youtube.com/user/privatepropertySA" target="_blank"></a>,
#  <a class="googlePlus" href="http://plus.google.com/+privateproperty/posts" target="_blank"></a>,
#  <a href="/careers">Careers</a>,
#  <a href="/ContactUs.aspx">Contact Us</a>,
#  <a href="/terms-and-conditions">Terms &amp; Conditions</a>,
#  <a href="/sa-womens-hockey">Sponsorships</a>]

# %% [markdown]
# If multiple tag names are provided in a list then tags that match *any* of those names with be returned.

# %%
soup.find_all(['h2', 'h3'])

# %% [markdown]
# You can pass a function as the `name` argument, in which case `find_all()` will return only those tags for which the function evaluates to `True`.

# %%
def links_with_id(tag):
    return tag.name == "a" and tag.has_attr('id')

# %%
soup.find_all(links_with_id)

# %% [markdown]
# You don't need to start searching from the top of the document. Any `Tag` can be the starting point for a search, in which case only that portion of the document tree will be traversed.

# %%
soup.section.find_all('p')

# %% [markdown]
# ### Search by Attributes

# %%
soup.find_all(attrs = {'class': 'topMenu'})

# %% [markdown]
# If multiple attributes are provided then they are combined with logical OR.

# %% [markdown]
# ### Search by Text Content
#
# You can search for text content by using the `text` argument to `find_all()`.

# %%
soup.find_all(text='Bedrooms')

# %% [markdown]
# Regular expressions work well with a text search.

# %%
soup.find_all(text=re.compile('B.*rooms'))

# %% [markdown]
# The `text` argument can be combined with tag name to select only specific tags which contain the text.

# %%
soup.find_all('span', text=re.compile('B.*rooms'))

# %% [markdown]
# ### Search with Keywords

# %%
soup.find_all(id='loginSignup')

# %% [markdown]
# Note that you can't specify `class` as a keyword argument because it's a reserved word in Python. Instead you need to use `class_`.

# %%
soup.find_all('a', class_='topMenu')

# %% [markdown]
# The combination of keyword arguments and regular expressions can be rather powerful.

# %%
soup.find_all(href=re.compile("^/to-rent"))

# %% [markdown]
# ### Limiting the Number of Results

# %%
soup.find_all(href=re.compile("^/to-rent"), limit = 2)

# %% [markdown]
# ### Recursing into the Document Tree
#
# With the `recursive` argument set to `False` only direct children will be considered.

# %% [markdown]
# ### Searching for Parents
#
# The methods `find_parents()` and `find_parent()` accept the same arguments as `find_all()` and `find()` respectively.
#
# These methods allow you to search a tag's parents.
#
# You'll probably find that the `parent` and `parents` attributes are sufficient for your purposes though.

# %% [markdown]
# ### Searching for Siblings
#
# The methods `find_next_siblings()` and `find_next_sibling()` accept the same arguments as `find_all()` and `find()` respectively.
#
# These are probably more useful than the `next_sibling` and `next_siblings` attributes because they return tags not strings.

# %%
for sibling in soup.h1.next_siblings:
    print(repr(sibling))

# %%
soup.h1.next_sibling

# %%
soup.h1.find_next_sibling('a')

# %% [markdown]
# The methods `find_previous_siblings()` and `find_previous_sibling()` are analogous but allow you to search siblings in the opposite direction.

# %% [markdown]
# ## Using CSS Selectors

# %% [markdown]
# Use the `select()` method to pass in a CSS selector.

# %%
soup.select('div.topLeft > div > div.titleContainer > h2')

# %% [markdown]
# You can choose only the first match by using `select_one()`.

# %%
soup.select_one('div.topLeft > div > div.titleContainer > h2')

# %% [markdown]
# ## Output
#
# The `prettify()` method can be used to neatly format tags. Beautiful Soup will internally convert [HTML entities](https://dev.w3.org/html5/html-author/charref) into the equivalent [Unicode](https://en.wikipedia.org/wiki/Unicode) characters. You can choose different output formats by providing a `formatter` argument to `prettify()`.

# %% [markdown]
# ### Text from Tags
#
# We've seen that the `string` attribute extracts the text content from a tag. But what about nested tags?

# %%
price = soup.select_one('div.topLeft > div > div.titleContainer > h2')
price

# %% [markdown]
# We can extract the textual content from a whole chunk of HTML using the `get_text()` method.

# %%
price.get_text()

# %% [markdown]
# That's far from ideal. We'll strip white space from each tag's text.

# %%
price.get_text(strip = True)

# %% [markdown]
# Then specify how strings from different tags are joined together.

# %%
price.get_text(" ", strip = True)
